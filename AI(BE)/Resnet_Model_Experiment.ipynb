# %%
# !pip install facenet-pytorch
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 5.2 MB/s
# ...

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %%
import torch
import torch.nn as nn
from torch import optim
checkpoint = torch.load('/content/drive/MyDrive/InceptionResNetV1_ArcFace.pt')
facenet = checkpoint.model
facenet.to(device)
facenet.eval()

facenet
# Out:
# InceptionResnet(
#   (net): InceptionResnetV1(
#     (conv2d_1a): BasicConv2d(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (conv2d_2a): BasicConv2d(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (conv2d_2b): BasicConv2d(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2d_3b): BasicConv2d(
#       (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
from facenet_pytorch import MTCNN
from PIL import Image


mtcnn = MTCNN(image_size=128,margin=0)
# Get cropped and prewhitened image temtcnn = MTCNN(keep_all=True, device='cuda:0')
# Out:
# None

# %%
img_cropped = mtcnn(img,save_path='single_image.jpg')

# %%
img_embedding1 = facenet(img_cropped.unsqueeze(0))

# %%
img2 = Image.open('/content/drive/MyDrive/unnamed.png')
img_image2 = mtcnn(img2,save_path='single_image.jpg')
img_embedding2 = facenet(img_image2.unsqueeze(0))

# %%
import numpy
dist = numpy.linalg.norm(img_embedding1.detach().numpy()-img_embedding2.detach().numpy())

# %%
img_embedding1.detach().numpy().shape
# Out:
# (1, 512)

# %%
print(dist)
# Out:
# 0.60200465

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from facenet_pytorch import MTCNN
from PIL import Image
import numpy
mtcnn = MTCNN(image_size=128,margin=0)
img_image2 = mtcnn(img2,save_path='single_image.jpg')
img_embedding2 = facenet(img_image2.unsqueeze(0))

# %%
def img_to_embedding(image_path, facenet):
    image = Image.open(image_path)
    image_cropped = mtcnn(image,save_path='single_image.jpg')
    img_embedding = facenet(image_cropped.unsqueeze(0))
    return img_embedding

# %%
def l2distance(input_embedding, output_embedding):
  dist = numpy.linalg.norm(input_embedding.detach().numpy()-output_embedding.detach().numpy())
  return dist

# %%
mtcnn = MTCNN(image_size=128,margin=0)

db = {}
char = '/content/drive/MyDrive/image_processed/김범준_1.jpg'
# db["김범준_1"] = img_to_embedding('/content/drive/MyDrive/image_processed/김범준_1.jpg',facenet)
db["김범준_2"] = img_to_embedding('/content/drive/MyDrive/image_processed/김범준_2.jpg',facenet)
db["김범준_3"] = img_to_embedding('/content/drive/MyDrive/image_processed/김범준_3.jpg',facenet)
db["이길동_1"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_1.jpg',facenet)
db["이길동_2"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_2.jpg',facenet)
db["이길동_3"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_3.jpg',facenet)
db["박시창_1"] = img_to_embedding('/content/drive/MyDrive/SichangPark_1.jpg',facenet)
db["박시창_2"] = img_to_embedding('/content/drive/MyDrive/SichangPark_2.jpg',facenet)
db["박시창_3"] = img_to_embedding('/content/drive/MyDrive/image_processed/박시창_3.jpg',facenet)
db["정인우_1"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_1.jpg',facenet)
db["정인우_2"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_2.jpg',facenet)
# db["정인우_3"] = img_to_embedding('/content/drive/MyDrive/image_processed/박찬혁_3.jpg',facenet)
db["김동병_1"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_1.jpg',facenet)
db["정명진_1"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_1.jpg',facenet)
db["정명진_2"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_2.jpg',facenet)
db["정명진_3"] = img_to_embedding('/content/drive/MyDrive/image_processed/***_3.jpg',facenet)

# %%
image = Image.open('/content/drive/MyDrive/캡처.JPG')
image_cropped = mtcnn(image,save_path='single_image.jpg')
img_embedding = facenet(image_cropped.unsqueeze(0))

# %%
image_cropped.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-1ed3bd810ace> in <module>()
# ----> 1 image_cropped.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'

# %%
l2distance(db["김범준_2"],db["김범준_3"])
# Out:
# 0.33604687

# %%
identity = ""
minimum = 100.0
for key, value in db.items():
  
  if l2distance(img_embedding, db[key]) < minimum:
    minimum = l2distance(img_embedding, db[key])
    identity = key
    print(key)
    print(minimum)
# Out:
# 김범준_2
# 1.1179223
# 김범준_3
# 1.0444199
# 이길동_1
# 0.7169863
# 이길동_3
# 0.6946796

# %%
import pickle
